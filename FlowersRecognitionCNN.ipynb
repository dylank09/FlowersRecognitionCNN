#   inflating: tulip/8713397358_0505cc0176_n.jpg
#   inflating: tulip/8713397694_bcbcbba2c2_n.jpg
#   inflating: tulip/8713398114_bc96f1b624_n.jpg
#   inflating: tulip/8713398614_88202e452e_n.jpg
#   inflating: tulip/8713398906_28e59a225a_n.jpg
#  extracting: tulip/8713407768_f880df361f.jpg
#   inflating: tulip/8717900362_2aa508e9e5.jpg
#   inflating: tulip/8722514702_7ecc68691c.jpg
#   inflating: tulip/8723767533_9145dec4bd_n.jpg
#   inflating: tulip/8729501081_b993185542_m.jpg
#   inflating: tulip/8733586143_3139db6e9e_n.jpg
#   inflating: tulip/8748266132_5298a91dcf_n.jpg
#   inflating: tulip/8750288831_5e49a9f29b.jpg
#   inflating: tulip/8757486380_90952c5377.jpg
#   inflating: tulip/8758464923_75a5ffe320_n.jpg
#   inflating: tulip/8758519201_16e8d2d781_n.jpg
#   inflating: tulip/8759594528_2534c0ec65_n.jpg
#   inflating: tulip/8759597778_7fca5d434b_n.jpg
#   inflating: tulip/8759601388_36e2a50d98_n.jpg
#   inflating: tulip/8759606166_8e475013fa_n.jpg
#   inflating: tulip/8759618746_f5e39fdbf8_n.jpg
#   inflating: tulip/8762189906_8223cef62f.jpg
#   inflating: tulip/8762193202_0fbf2f6a81.jpg
#   inflating: tulip/8768645961_8f1e097170_n.jpg
#   inflating: tulip/8817622133_a42bb90e38_n.jpg
#   inflating: tulip/8838347159_746d14e6c1_m.jpg
#   inflating: tulip/8838354855_c474fc66a3_m.jpg
#   inflating: tulip/8838914676_8ef4db7f50_n.jpg
#   inflating: tulip/8838975946_f54194894e_m.jpg
#   inflating: tulip/8838983024_5c1a767878_n.jpg
#   inflating: tulip/8892851067_79242a7362_n.jpg
#   inflating: tulip/8904780994_8867d64155_n.jpg
#   inflating: tulip/8908062479_449200a1b4.jpg
#   inflating: tulip/8908097235_c3e746d36e_n.jpg
#   inflating: tulip/9019694597_2d3bbedb17.jpg
#   inflating: tulip/9030467406_05e93ff171_n.jpg
#   inflating: tulip/9048307967_40a164a459_m.jpg
#   inflating: tulip/924782410_94ed7913ca_m.jpg
#   inflating: tulip/9378657435_89fabf13c9_n.jpg
#   inflating: tulip/9444202147_405290415b_n.jpg
#   inflating: tulip/9446982168_06c4d71da3_n.jpg
#   inflating: tulip/9831362123_5aac525a99_n.jpg
#   inflating: tulip/9870557734_88eb3b9e3b_n.jpg
#   inflating: tulip/9947374414_fdf1d0861c_n.jpg
#  extracting: tulip/9947385346_3a8cacea02_n.jpg
#   inflating: tulip/9976515506_d496c5e72c.jpg

# %%
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import classification_report, log_loss, accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Dataset

# %%
# here we list the types of flowers we will attempt to classify

CLASSES = ['daisy','dandelion','rose','sunflower','tulip'] 
print("Number of flower classes: ", len(CLASSES))
# Out:
# Number of flower classes:  5

# %%
# here we load a single image from the unzipped folder daisy 

dir = './'
img = load_img(dir + CLASSES[0] + "/100080576_f52e8ee070_n.jpg")
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
x = img_to_array(img)
print(x.shape)
# Out:
# (263, 320, 3)

# %% [markdown]
# ### Data-preprocessing

# %% [markdown]
#  - Read in the images from the different sub folders
#  - CV2 reads in as BGR so we convert this to RGB
#  - Normalize the image arrays for training

# %%
IMG_SIZE = 48
training_data = []
numsOfEachFlowerClass = []

def create_training_data():
  
  for c in CLASSES:
    #join the class name to the directory
    path = os.path.join(dir,c)
    count = 0
    class_num = CLASSES.index(c)
    for im in os.listdir(path):
      if im[-4:]=='.jpg':
        try:
          img_array = cv2.imread(os.path.join(path, im))
          image = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
          resized_img_array = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
          count += 1

          #normalise the image pixel values
          image = resized_img_array/255.0
          
          training_data.append([image, class_num])
        except Exception as e:
          pass
    numsOfEachFlowerClass.append(count)

create_training_data()

# %% [markdown]
# Investigate the data.
#
# It is a big dataset with over 4000 images.
# It has a mean of roughly 2 which means that the data is balanced as the class numbers go from 0 to 4

# %%
df = pd.DataFrame(training_data, columns=['Image Arrays', 'Flower Class'])
df.describe()
# Out:
#        Flower Class
# count   4317.000000
# mean       2.028029
# std        1.425767
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        4.000000

# %%
# Correlation
# Since we only have the Flower Class to correlate - we cannot perform correlation on the data

# %%
import random

# we must shuffle the data because at the moment, the data is in groups of classes
# i.e. the first 800 rows are Daisies and we dont want the model to be overfitted
# on Daisies and then switching to another class
random.shuffle(training_data)

# %%
#validate the data is shuffled by seeing if the class numbers vary
for im in training_data[:10]:
  print(im[1])
# Out:
# 1
# 2
# 1
# 0
# 1
# 4
# 2
# 1
# 2
# 0

# %%
#sample the first 20 images in the training data
plt.figure(figsize=(10,10))
for i in range(20):
    
    plt.subplot(4,5,i+1)
    plt.grid(False)
    img = training_data[i][0]
    plt.imshow(img)
    plt.xlabel(CLASSES[training_data[i][1]])
plt.show()

# %% [markdown]
# We investigated the data types and if the columns have null values or not

# %% [markdown]
# ### Visualisation
# We wanted to visualise the correlation of the data;
# try see which variables might indicate a the likelyhood stroke

# %%
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(CLASSES, numsOfEachFlowerClass, color ='blue',
        width = 0.4)
 
plt.xlabel("Categories")
plt.ylabel("No of images")
plt.title("Total number of images in categories")
plt.show()

# %% [markdown]
# # Preparing Test and Train sets

# %%
X = []
y = []

# %% [markdown]
# We separate the training data into features (image arrays) and labels (flower class)

# %%
for features, label in training_data[:-2]:
  X.append(features)
  y.append(label)

# reshape the image arrays to be 48 x 48 pixels and to be RGB hence the '3'
X = np.array(X).reshape((-1, IMG_SIZE, IMG_SIZE, 3))

# here we converts our label/class array of integers to binary class matrix.
y = tf.keras.utils.to_categorical(y)
y = np.array(y)

# %%
print(X.shape)
print(y.shape)
# Out:
# (4315, 48, 48, 3)
# (4315, 5)

# %%
# we get train and test sets for each of the X and y
# the test size is 20% of the overall 
trainx, testx, trainy, testy = train_test_split(X,
                                                y,
                                                test_size=0.2,
                                                random_state=44)

# %%
print(trainx.shape)
print(trainy.shape)
print(testx.shape)
print(testy.shape)
# Out:
# (3452, 48, 48, 3)
# (3452, 5)
# (863, 48, 48, 3)
# (863, 5)

# %% [markdown]
# # Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten,Conv2D,MaxPooling2D

# %%
from tensorflow.keras.models import Model

# %%
# here we perform some image augmentation on the images
# flip the images horizontally and vertically, roatate them, zoom on them etc.

datagen = ImageDataGenerator(horizontal_flip=True,vertical_flip=True,
                             rotation_range=20,zoom_range=0.2,
                            width_shift_range=0.2,height_shift_range=0.2,
                             shear_range=0.1,fill_mode="nearest")

# %%
# we initialise the dense net 201 with the correct input shape of the data
# we get the weights from imagenet
pretrained_model = tf.keras.applications.DenseNet201(input_shape=(48,48,3),
                                                      include_top=False,
                                                      weights='imagenet',
                                                      pooling='avg')
pretrained_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 2s 0us/step
# 74850304/74836368 [==============================] - 2s 0us/step

# %% [markdown]
# In this block, we define the inputs and outputs for the pretrained model.
#
# **activation**
# We use 'relu' for the Dense model layers
#
# We use 'softmax' for the output layer
# The output layer has a size of the number of flower classes in the dataset.

# %%
inputs = pretrained_model.input
x3 = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
outputs = tf.keras.layers.Dense(len(CLASSES), activation='softmax')(x3)
model = tf.keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# **Loss function**
#
# We first decided that **categorical_crossentropy** is the best choice as there are more than 2 flower classes. But we later found out that MSE gives us a significantly lower loss value.
#
#
# We tried using sparse_categorical_crossentropy but this did not match the shape of the data.
#
# **Optimizer**
#
# optimizer is '**adam**' in order to attempt to minimize the loss function as fast as possible. This gave us the best accuracy and the least loss.
#
# **Metrics**
#
# We want to see the accuracy of the model as it runs.

# %%
model.compile(loss='mse',
              optimizer='adam',
              metrics=['accuracy'])

# %% [markdown]
# We want to print out what the model looks like. We can see there are many layers including Batch Normalisation, Dense... etc.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  zero_padding2d (ZeroPadding2D)  (None, 54, 54, 3)   0           ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 24, 24, 64)   9408        ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 24, 24, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 24, 24, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 26, 26, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 12, 12, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 12, 12, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 12, 12, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 12, 12, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 12, 12, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 12, 12, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 12, 12, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 12, 12, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 12, 12, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 12, 12, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 12, 12, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 12, 12, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 12, 12, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 12, 12, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 12, 12, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 12, 12, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 12, 12, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 12, 12, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 12, 12, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 12, 12, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 12, 12, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 12, 12, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 12, 12, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 12, 12, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 12, 12, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 12, 12, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 6, 6, 128)    0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 6, 6, 128)   512         ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 6, 6, 128)    16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 6, 6, 160)   0           ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 6, 6, 160)   640         ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 6, 6, 160)   0           ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 6, 6, 128)    20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 6, 6, 192)   0           ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 6, 6, 192)   768         ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 6, 6, 192)   0           ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 6, 6, 128)    24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 6, 6, 224)   0           ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 6, 6, 224)   896         ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 6, 6, 224)   0           ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 6, 6, 128)    28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 6, 6, 256)   0           ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 6, 6, 256)   0           ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 6, 6, 128)    32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 6, 6, 288)   0           ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 6, 6, 288)   1152        ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 6, 6, 288)   0           ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 6, 6, 128)    36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 6, 6, 320)   0           ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 6, 6, 320)   1280        ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 6, 6, 320)   0           ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 6, 6, 128)    40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 6, 6, 352)   0           ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 6, 6, 352)   1408        ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 6, 6, 352)   0           ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 6, 6, 128)    45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 6, 6, 384)   0           ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 6, 6, 384)   1536        ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 6, 6, 384)   0           ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 6, 6, 128)    49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 6, 6, 416)   0           ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 6, 6, 416)   1664        ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 6, 6, 416)   0           ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 6, 6, 128)    53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 6, 6, 128)   512         ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 6, 6, 128)   0           ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 6, 6, 32)     36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 6, 6, 448)   0           ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 6, 6, 448)   1792        ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 6, 6, 448)   0           ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 6, 6, 128)    57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 6, 6, 128)   512         ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 6, 6, 128)   0           ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 6, 6, 32)     36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 6, 6, 480)   0           ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 6, 6, 480)   1920        ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 6, 6, 480)   0           ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 6, 6, 128)    61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 6, 6, 128)   512         ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 6, 6, 128)   0           ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 6, 6, 32)     36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 6, 6, 512)   0           ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 6, 6, 512)    2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 6, 6, 512)    0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 6, 6, 256)    131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 3, 3, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 3, 3, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 3, 3, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 3, 3, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 3, 3, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 3, 3, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 3, 3, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 3, 3, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 3, 3, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 3, 3, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 3, 3, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 3, 3, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 3, 3, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 3, 3, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 3, 3, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 3, 3, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 3, 3, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 3, 3, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 3, 3, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 3, 3, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 3, 3, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 3, 3, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 3, 3, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 3, 3, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 3, 3, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 3, 3, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 3, 3, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 3, 3, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 3, 3, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 3, 3, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 3, 3, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 3, 3, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 3, 3, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 3, 3, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 3, 3, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 3, 3, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 3, 3, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 3, 3, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 3, 3, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 3, 3, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 3, 3, 128)   0           ['conv4_block6_1_bn[0][0]']
#  n)
# ...
#
#  conv5_block25_1_conv (Conv2D)  (None, 1, 1, 128)    212992      ['conv5_block25_0_relu[0][0]']
#
#  conv5_block25_1_bn (BatchNorma  (None, 1, 1, 128)   512         ['conv5_block25_1_conv[0][0]']
#  lization)
#
#  conv5_block25_1_relu (Activati  (None, 1, 1, 128)   0           ['conv5_block25_1_bn[0][0]']
#  on)
#
#  conv5_block25_2_conv (Conv2D)  (None, 1, 1, 32)     36864       ['conv5_block25_1_relu[0][0]']
#
#  conv5_block25_concat (Concaten  (None, 1, 1, 1696)  0           ['conv5_block24_concat[0][0]',
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 1, 1, 1696)  6784        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 1, 1, 1696)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 1, 1, 128)    217088      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 1, 1, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 1, 1, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 1, 1, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 1, 1, 1728)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 1, 1, 1728)  6912        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 1, 1, 1728)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 1, 1, 128)    221184      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 1, 1, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 1, 1, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 1, 1, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 1, 1, 1760)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 1, 1, 1760)  7040        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 1, 1, 1760)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 1, 1, 128)    225280      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 1, 1, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 1, 1, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 1, 1, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 1, 1, 1792)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 1, 1, 1792)  7168        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 1, 1, 1792)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 1, 1, 128)    229376      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 1, 1, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 1, 1, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 1, 1, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 1, 1, 1824)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 1, 1, 1824)  7296        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 1, 1, 1824)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 1, 1, 128)    233472      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 1, 1, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 1, 1, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 1, 1, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 1, 1, 1856)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 1, 1, 1856)  7424        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 1, 1, 1856)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 1, 1, 128)    237568      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 1, 1, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 1, 1, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 1, 1, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 1, 1, 1888)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 1, 1, 1888)  7552        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 1, 1, 1888)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 1, 1, 128)    241664      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 1, 1, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 1, 1, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 1, 1, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 1, 1, 1920)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 1, 1, 1920)   7680        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 1, 1, 1920)   0           ['bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1920)        0           ['relu[0][0]']
#  2D)
#
#  dense (Dense)                  (None, 128)          245888      ['avg_pool[0][0]']
#
#  dense_1 (Dense)                (None, 5)            645         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 18,568,517
# Trainable params: 246,533
# Non-trainable params: 18,321,984
# __________________________________________________________________________________________________

# %% [markdown]
# **Fitting/Training the model**
#
# Epochs sets the number of iterations of the model. We chose 10 epochs after some testing to try get the best result without overfitting. This was also partially due to constraints of the system we used to run the model.
#
# Batch size splits the data into batches and processes them in parallel. We set this to 32 as we got the best results with this.
#
# Verbose is boolean and logs the output so we set verbose to **true**.
#
# We set the validation_data to the test sets. This is using an automatic validation dataset on our classification.

# %% [markdown]
# Now we save the models history so we can evaluate the accuracy and loss later

# %%
# here we fit the model. We apply the image data generator to perform data augmentation
# to prevent overfitting. 
# validation of the model is performed using the test sets 

hist = model.fit(datagen.flow(trainx,trainy,batch_size=32),
                 epochs=10, 
                 validation_data=(testx,testy)
)
# Out:
# Epoch 1/10
# 108/108 [==============================] - 59s 156ms/step - loss: 0.1098 - accuracy: 0.5773 - val_loss: 0.0922 - val_accuracy: 0.6686
# Epoch 2/10
# 108/108 [==============================] - 11s 99ms/step - loss: 0.0926 - accuracy: 0.6596 - val_loss: 0.0846 - val_accuracy: 0.6999
# Epoch 3/10
# 108/108 [==============================] - 10s 91ms/step - loss: 0.0862 - accuracy: 0.6929 - val_loss: 0.0868 - val_accuracy: 0.6802
# Epoch 4/10
# 108/108 [==============================] - 11s 99ms/step - loss: 0.0829 - accuracy: 0.6947 - val_loss: 0.0862 - val_accuracy: 0.6952
# Epoch 5/10
# 108/108 [==============================] - 10s 97ms/step - loss: 0.0823 - accuracy: 0.6947 - val_loss: 0.0837 - val_accuracy: 0.6790
# Epoch 6/10
# 108/108 [==============================] - 10s 90ms/step - loss: 0.0790 - accuracy: 0.7118 - val_loss: 0.0769 - val_accuracy: 0.7173
# Epoch 7/10
# 108/108 [==============================] - 10s 90ms/step - loss: 0.0774 - accuracy: 0.7167 - val_loss: 0.0773 - val_accuracy: 0.7161
# Epoch 8/10
# 108/108 [==============================] - 10s 91ms/step - loss: 0.0764 - accuracy: 0.7178 - val_loss: 0.0780 - val_accuracy: 0.7161
# Epoch 9/10
# 108/108 [==============================] - 11s 99ms/step - loss: 0.0738 - accuracy: 0.7231 - val_loss: 0.0795 - val_accuracy: 0.7092
# Epoch 10/10
# 108/108 [==============================] - 10s 91ms/step - loss: 0.0745 - accuracy: 0.7271 - val_loss: 0.0783 - val_accuracy: 0.7010

# %% [markdown]
# # Results
#
# Here we consider the results.

# %% [markdown]
# 'y_pred' is an array containing the predictions from the
# model based on the test set.

# %% [markdown]
# Here we calculate metrics precision, recall, F1 score and support.

# %%
y_pred = model.predict(testx)

# this array will contain the predicted class number of each image from 0 to 4
predicted_classes = np.argmax(y_pred, axis=1)

ground = np.argmax(testy, axis=1)
print(classification_report(ground,predicted_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.51      0.64       160
#            1       0.69      0.81      0.74       206
#            2       0.70      0.63      0.66       152
#            3       0.69      0.79      0.74       141
#            4       0.66      0.74      0.69       204
#
#     accuracy                           0.70       863
#    macro avg       0.72      0.69      0.70       863
# weighted avg       0.72      0.70      0.70       863

# %% [markdown]
# Here we plot the first 20 images of the dataset and their actual vs their predicted flower class

# %%
plt.figure(figsize=(12,12))

for i in range(20):
    
    plt.subplot(4,5,i+1)
    plt.grid(False)
    img = training_data[i][0]
    plt.imshow(img)
    img = np.array(img)
    img = np.expand_dims(img, axis=0)
    
    prediction = model.predict(img)
    value = np.argmax(prediction)
    plt.xlabel("Actual: "+ CLASSES[training_data[i][1]] 
               + "\n Predicted: " + CLASSES[value])
    
plt.show()

# you can see that it predicts a lot of the flower images well

# %% [markdown]
# # Evaluation
#
# Evaluate the model on the test set
#
# Tracking Results with different hyper params:
#
# **Loss Function**
# 1. Categorical_crossentropy: ~70% loss
# 2. MSE: ~7% loss
#
# We decided to chose MSE as to estimate the loss of the model so that the weights can be changed to reduce the loss.
#
# **Optimizers**:
#
# 1. adam -> ~70.5% accuracy, 7% loss
# 2. SGD -> ~70% accuracy and 8% loss
# 3. RMSProp -> ~67% accuracy, 12% loss
# 4. adamax -> 65% accuracy, 9% loss
#
#
# **Batch Size**
#
# We increased the batch size and quickly noticed the accuracy reducing. Therefore we decided on a batch size of 32 in order to speed up computation while maintaining good accuracy.

# %%
score = model.evaluate(testx, testy, verbose=1)
print("loss = " + str(score[0]*100) + "% \naccuracy: "+ str(score[1]*100) + "%")
# Out:
# 27/27 [==============================] - 2s 71ms/step - loss: 0.0783 - accuracy: 0.7010
# loss = 7.834026962518692%
# accuracy: 70.1042890548706%

# %% [markdown]
# Here we count how many predictions the model got right.
#
# We can see from this how much it got right and wrong.

# %%
# countWrong = 0

# for i in range(len(training_data)):
    
#     img = training_data[i][0]
#     img = np.array(img)
#     img = np.expand_dims(img, axis=0)
    
#     prediction = model.predict(img)
#     value = np.argmax(prediction)
    
#     if training_data[i][1] != value:
#       countWrong += 1

# %%
# print("Number of wrong predictions: " + str(countWrong) + " from " + str(len(training_data)) + " test cases")

# %% [markdown]
# **Check for overfitting and underfitting**
#
# A model is thought to be overfitting if your validation loss has been increasing and underfit is the validation loss is still decreasing.

# %% [markdown]
# Next we plot how the accuracy changed over the Epochs on both the train and validation data.

# %%
get_acc = hist.history['accuracy']
value_acc = hist.history['val_accuracy']
get_loss = hist.history['loss']
validation_loss = hist.history['val_loss']

epochs = range(len(get_acc))
plt.plot(epochs, get_acc, 'r', label='Accuracy of Training data')
plt.plot(epochs, value_acc, 'b', label='Accuracy of Validation data')
plt.title('Training vs validation accuracy')
plt.legend(loc=0)
plt.figure()
plt.show()

# %% [markdown]
# We can see above that the accuracy seems to level out between epochs 4 and 10.

# %% [markdown]
# Plot the validation set loss over the epochs

# %%
epochs = range(len(get_loss))
plt.plot(epochs, get_loss, 'r', label='Loss of Training data')
plt.plot(epochs, validation_loss, 'b', label='Loss of Validation data')
plt.title('Training vs validation loss')
plt.legend(loc=0)
plt.figure()
plt.show()

# %% [markdown]
# We had a much higher loss with categorical_crossentropy than we now have with MSE

# %% [markdown]
# # Experimentations

# %% [markdown]
# ### 1. We attempted to perform a simple 3 layer CNN to the data. This resulted in poor accuracy but it was a good starting point.

# %%
# model = Sequential()

# model.add(Conv2D(64, (3,3), input_shape = X.shape[1:]))
# model.add(Activation("relu"))
# model.add(MaxPooling2D(pool_size=(2,2)))

# model.add(Conv2D(64, (3,3)))
# model.add(Activation("relu"))
# model.add(MaxPooling2D(pool_size=(2,2)))

# model.add(Conv2D(64, (3,3)))
# model.add(Activation("relu"))
# model.add(MaxPooling2D(pool_size=(2,2)))

# model.add(Flatten())
# model.add(Dense(64))

# model.add(Dense(1))
# model.add(Activation("sigmoid"))

# %%
# model.compile(loss='categorical_crossentropy',
#               optimizer='adam',  
#               metrics=['accuracy'])

# %%
# model.fit(X, y, batch_size=32, validation_split=0.1)
